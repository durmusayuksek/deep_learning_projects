# %% [markdown]
# <h1 style="text-align: center;">Churn Prediction for Bank Customer (Artificial Neural Networks)<h1>

# %% [markdown]
# ## 1. Dataset Info

# %% [markdown]
# We have a dataset in which there are details of a bank's customers and the target variable is a binary variable reflecting the fact whether the customer left the bank (closed his/her account) or s/he continues to be a customer.

# %% [markdown]
# ## 2. Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10,6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 3. Load Data

# %%
df = pd.read_csv('Churn_Modeling.csv')

# %% [markdown]
# ## 4. Exploratory Data Analysis and Visualization

# %% [markdown]
# 1. Implement basic steps to see how is your data looks like
# 2. Check for missing values
# 3. Drop the features that not suitable for modelling
# 4. Implement basic visualization steps such as histogram, countplot, heatmap
# 5. Convert categorical variables to dummy variables

# %%
df.head().T
# Out:
#                          0          1          2         3          4
# RowNumber                1          2          3         4          5
# CustomerId        15634602   15647311   15619304  15701354   15737888
# Surname           Hargrave       Hill       Onio      Boni   Mitchell
# CreditScore            619        608        502       699        850
# Geography           France      Spain     France    France      Spain
# Gender              Female     Female     Female    Female     Female
# Age                     42         41         42        39         43
# Tenure                   2          1          8         1          2
# Balance              0.000  83807.860 159660.800     0.000 125510.820
# NumOfProducts            1          1          3         2          1
# HasCrCard                1          0          1         0          1
# IsActiveMember           1          1          0         0          1
# EstimatedSalary 101348.880 112542.580 113931.570 93826.630  79084.100
# Exited                   1          0          1         0          0

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.describe().T
# Out:
#                     count         mean       std          min          25%  \
# RowNumber       10000.000     5000.500  2886.896        1.000     2500.750
# CustomerId      10000.000 15690940.569 71936.186 15565701.000 15628528.250
# CreditScore     10000.000      650.529    96.653      350.000      584.000
# Age             10000.000       38.922    10.488       18.000       32.000
# Tenure          10000.000        5.013     2.892        0.000        3.000
# Balance         10000.000    76485.889 62397.405        0.000        0.000
# NumOfProducts   10000.000        1.530     0.582        1.000        1.000
# HasCrCard       10000.000        0.706     0.456        0.000        0.000
# IsActiveMember  10000.000        0.515     0.500        0.000        0.000
# EstimatedSalary 10000.000   100090.240 57510.493       11.580    51002.110
# Exited          10000.000        0.204     0.403        0.000        0.000
#
#                          50%          75%          max
# RowNumber           5000.500     7500.250    10000.000
# CustomerId      15690738.000 15753233.750 15815690.000
# CreditScore          652.000      718.000      850.000
# Age                   37.000       44.000       92.000
# Tenure                 5.000        7.000       10.000
# Balance            97198.540   127644.240   250898.090
# NumOfProducts          1.000        2.000        4.000
# HasCrCard              1.000        1.000        1.000
# IsActiveMember         1.000        1.000        1.000
# EstimatedSalary   100193.915   149388.247   199992.480
# Exited                 0.000        0.000        1.000

# %%
df.isnull().any().any()
# Out:
# False

# %%
sns.histplot(df.CreditScore);

# %%
sns.countplot(df.Geography);

# %%
sns.countplot(df.Gender);

# %%
sns.countplot(df.Age)
plt.xticks(rotation=90);

# %%
sns.countplot(df.Tenure);

# %%
sns.distplot(df.Balance);

# %%
len(df[df.Balance == 0])
# Out:
# 3617

# %%
df.NumOfProducts.value_counts()
# Out:
# 1    5084
# 2    4590
# 3     266
# 4      60
# Name: NumOfProducts, dtype: int64

# %%
sns.countplot(df.HasCrCard);

# %%
sns.countplot(df.IsActiveMember);

# %%
sns.distplot(df.EstimatedSalary);

# %%
sns.countplot(df.Exited);

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(), annot=True, cmap='viridis_r');

# %%
df_new = df.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1)

# %%
plt.figure(figsize = (8,10))
df_new.corr()['Exited'].sort_values().drop("Exited").plot(kind = "barh");

# %%
geo = pd.get_dummies(df_new['Geography'], prefix='geo')
gender = pd.get_dummies(df_new['Gender'])
df_new2 = pd.concat([df_new, geo, gender], axis = 1)

# %%
df_new2.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2      0.000              1
# 1          608     Spain  Female   41       1  83807.860              1
# 2          502    France  Female   42       8 159660.800              3
# 3          699    France  Female   39       1      0.000              2
# 4          850     Spain  Female   43       2 125510.820              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited  geo_France  \
# 0          1               1       101348.880       1           1
# 1          0               1       112542.580       0           0
# 2          1               0       113931.570       1           1
# 3          0               0        93826.630       0           1
# 4          1               1        79084.100       0           0
#
#    geo_Germany  geo_Spain  Female  Male
# 0            0          0       1     0
# 1            0          1       1     0
# 2            0          0       1     0
# 3            0          0       1     0
# 4            0          1       1     0

# %%
df_final = df_new2.drop(['Geography', 'Gender'], axis = 1)

# %%
df_final.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2      0.000              1          1
# 1          608   41       1  83807.860              1          0
# 2          502   42       8 159660.800              3          1
# 3          699   39       1      0.000              2          0
# 4          850   43       2 125510.820              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  geo_France  geo_Germany  \
# 0               1       101348.880       1           1            0
# 1               1       112542.580       0           0            0
# 2               0       113931.570       1           1            0
# 3               0        93826.630       0           1            0
# 4               1        79084.100       0           0            0
#
#    geo_Spain  Female  Male
# 0          0       1     0
# 1          1       1     0
# 2          0       1     0
# 3          0       1     0
# 4          1       1     0

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CreditScore      10000 non-null  int64
#  1   Age              10000 non-null  int64
#  2   Tenure           10000 non-null  int64
#  3   Balance          10000 non-null  float64
#  4   NumOfProducts    10000 non-null  int64
#  5   HasCrCard        10000 non-null  int64
#  6   IsActiveMember   10000 non-null  int64
#  7   EstimatedSalary  10000 non-null  float64
#  8   Exited           10000 non-null  int64
#  9   geo_France       10000 non-null  uint8
#  10  geo_Germany      10000 non-null  uint8
#  11  geo_Spain        10000 non-null  uint8
#  12  Female           10000 non-null  uint8
#  13  Male             10000 non-null  uint8
# dtypes: float64(2), int64(7), uint8(5)
# memory usage: 752.1 KB

# %%
plt.figure(figsize = (8,10))
df_final.corr()['Exited'].sort_values().drop("Exited").plot(kind = "barh");

# %% [markdown]
# ## 5. Preprocessing of Data
# - Train | Test Split, Scalling

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
X = df_final.drop('Exited', axis=1)
y = df_final['Exited'].values

# %%
seed = 42

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify = y, test_size = 0.10, random_state = seed)

# %%
scaler = MinMaxScaler()

# %%
X_train= scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### 5.1. Import related libraries

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import plot_roc_curve, roc_auc_score, roc_curve
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### 5.2. Creating Model

# %% [markdown]
# ### 5.2.1. Without class_weight

# %%
from tensorflow.keras.optimizers import Adam

# %%
tf.random.set_seed(seed)

model = Sequential()

model.add(Dense(20, activation = "relu", input_dim = X_train.shape[1]))
model.add(Dense(15, activation = "relu"))
model.add(Dense(10, activation = "relu"))
model.add(Dense(1, activation = "sigmoid"))

tb_callback = tf.keras.callbacks.TensorBoard(log_dir='logs/', histogram_freq=1)

model.compile(optimizer = Adam(lr = 0.003), loss = "binary_crossentropy", metrics = ["accuracy"])

# buraya Recall da yazilabilir

# %%
model.fit(x = X_train, y = y_train, validation_split = 0.1, batch_size = 32, epochs = 500, 
          verbose=1, callbacks = [tb_callback])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 20)                280
#
#  dense_9 (Dense)             (None, 15)                315
#
#  dense_10 (Dense)            (None, 10)                160
#
#  dense_11 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 766
# Trainable params: 766
# Non-trainable params: 0
# _________________________________________________________________

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.head()
# Out:
#    loss  accuracy  val_loss  val_accuracy
# 0 0.476     0.800     0.420         0.826
# 1 0.428     0.816     0.405         0.827
# 2 0.390     0.835     0.335         0.868
# 3 0.372     0.844     0.318         0.877
# 4 0.363     0.845     0.311         0.874

# %%
loss_df.plot();

# %%
model.evaluate(X_test, y_test, verbose=0)
# Out:
# [0.4323722720146179, 0.8489999771118164]

# %%
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print("loss : ", loss)
print("accuracy : ", accuracy)
# Out:
# loss :  0.4323722720146179
# accuracy :  0.8489999771118164

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[762  34]
#  [117  87]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91       796
#            1       0.72      0.43      0.54       204
#
#     accuracy                           0.85      1000
#    macro avg       0.79      0.69      0.72      1000
# weighted avg       0.84      0.85      0.83      1000

# %% [markdown]
# ### 5.2.2. Without class_weight (with Early stop)

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
tf.random.set_seed(seed)

model = Sequential()

model.add(Dense(20, activation = "relu", input_dim = X_train.shape[1]))
model.add(Dense(15, activation = "relu"))
model.add(Dense(10, activation = "relu"))
model.add(Dense(1, activation = "sigmoid"))

model.compile(optimizer = Adam(lr = 0.003), loss = "binary_crossentropy", metrics = ["accuracy"])

# %%
early_stop = EarlyStopping(monitor = "val_loss", mode = "auto", verbose = 1, patience = 15)

# %%
model.fit(x = X_train, y = y_train, validation_split = 0.1, batch_size = 32, epochs = 500, 
          verbose = 1, callbacks = [early_stop])
# Out:
# Epoch 1/500
# 254/254 [==============================] - 1s 3ms/step - loss: 0.4765 - accuracy: 0.7995 - val_loss: 0.4199 - val_accuracy: 0.8256
# Epoch 2/500
# 254/254 [==============================] - 1s 2ms/step - loss: 0.4284 - accuracy: 0.8159 - val_loss: 0.4049 - val_accuracy: 0.8267
# Epoch 3/500
# 254/254 [==============================] - 1s 2ms/step - loss: 0.3899 - accuracy: 0.8347 - val_loss: 0.3347 - val_accuracy: 0.8678
# Epoch 4/500
# 254/254 [==============================] - 1s 2ms/step - loss: 0.3719 - accuracy: 0.8438 - val_loss: 0.3176 - val_accuracy: 0.8767
# Epoch 5/500
# 254/254 [==============================] - 1s 2ms/step - loss: 0.3626 - accuracy: 0.8449 - val_loss: 0.3107 - val_accuracy: 0.8744
# Epoch 6/500
# 254/254 [==============================] - 1s 2ms/step - loss: 0.3567 - accuracy: 0.8525 - val_loss: 0.3086 - val_accuracy: 0.8811
# Epoch 7/500
# 254/254 [==============================] - 1s 2ms/step - loss: 0.3520 - accuracy: 0.8547 - val_loss: 0.3068 - val_accuracy: 0.8822
# Epoch 8/500
# 254/254 [==============================] - 1s 2ms/step - loss: 0.3502 - accuracy: 0.8538 - val_loss: 0.3028 - val_accuracy: 0.8900
# Epoch 9/500
# 254/254 [==============================] - 1s 2ms/step - loss: 0.3486 - accuracy: 0.8570 - val_loss: 0.3110 - val_accuracy: 0.8778
# Epoch 10/500
# 254/254 [==============================] - 1s 2ms/step - loss: 0.3471 - accuracy: 0.8556 - val_loss: 0.2967 - val_accuracy: 0.8833
# Epoch 11/500
# 254/254 [==============================] - 1s 3ms/step - loss: 0.3462 - accuracy: 0.8536 - val_loss: 0.3130 - val_accuracy: 0.8878
# Epoch 12/500
# 254/254 [==============================] - 1s 3ms/step - loss: 0.3464 - accuracy: 0.8586 - val_loss: 0.2989 - val_accuracy: 0.8844
# Epoch 13/500
# 254/254 [==============================] - 1s 3ms/step - loss: 0.3438 - accuracy: 0.8607 - val_loss: 0.2991 - val_accuracy: 0.8856
# Epoch 14/500
# 254/254 [==============================] - 1s 2ms/step - loss: 0.3437 - accuracy: 0.8593 - val_loss: 0.3067 - val_accuracy: 0.8956
# Epoch 15/500
# 254/254 [==============================] - 1s 2ms/step - loss: 0.3433 - accuracy: 0.8599 - val_loss: 0.3033 - val_accuracy: 0.8822
# Epoch 16/500
# 254/254 [==============================] - 1s 2ms/step - loss: 0.3420 - accuracy: 0.8575 - val_loss: 0.2940 - val_accuracy: 0.8900
# Epoch 17/500
# 254/254 [==============================] - 1s 2ms/step - loss: 0.3407 - accuracy: 0.8595 - val_loss: 0.2938 - val_accuracy: 0.8956
# Epoch 18/500
# 254/254 [==============================] - 1s 2ms/step - loss: 0.3418 - accuracy: 0.8609 - val_loss: 0.2914 - val_accuracy: 0.8867
# Epoch 19/500
# 254/254 [==============================] - 1s 5ms/step - loss: 0.3403 - accuracy: 0.8574 - val_loss: 0.2956 - val_accuracy: 0.8867
# Epoch 20/500
# 254/254 [==============================] - 1s 5ms/step - loss: 0.3399 - accuracy: 0.8598 - val_loss: 0.2976 - val_accuracy: 0.8767
# Epoch 21/500
# 254/254 [==============================] - 1s 3ms/step - loss: 0.3379 - accuracy: 0.8602 - val_loss: 0.2938 - val_accuracy: 0.8922
# Epoch 22/500
# 254/254 [==============================] - 1s 3ms/step - loss: 0.3406 - accuracy: 0.8600 - val_loss: 0.2943 - val_accuracy: 0.8933
# Epoch 23/500
# 254/254 [==============================] - 1s 3ms/step - loss: 0.3411 - accuracy: 0.8575 - val_loss: 0.2938 - val_accuracy: 0.8856
# Epoch 24/500
# 254/254 [==============================] - 1s 3ms/step - loss: 0.3387 - accuracy: 0.8615 - val_loss: 0.2966 - val_accuracy: 0.8889
# Epoch 25/500
# 254/254 [==============================] - 1s 3ms/step - loss: 0.3377 - accuracy: 0.8584 - val_loss: 0.2983 - val_accuracy: 0.8833
# Epoch 26/500
# 254/254 [==============================] - 1s 3ms/step - loss: 0.3370 - accuracy: 0.8601 - val_loss: 0.2991 - val_accuracy: 0.8911
# Epoch 27/500
# 254/254 [==============================] - 1s 2ms/step - loss: 0.3379 - accuracy: 0.8590 - val_loss: 0.3058 - val_accuracy: 0.8900
# Epoch 28/500
# 254/254 [==============================] - 1s 2ms/step - loss: 0.3367 - accuracy: 0.8593 - val_loss: 0.2935 - val_accuracy: 0.8844
# Epoch 29/500
# 254/254 [==============================] - 1s 2ms/step - loss: 0.3342 - accuracy: 0.8615 - val_loss: 0.2943 - val_accuracy: 0.8856
# Epoch 30/500
# 254/254 [==============================] - 1s 2ms/step - loss: 0.3352 - accuracy: 0.8631 - val_loss: 0.3008 - val_accuracy: 0.8867
# Epoch 31/500
# 254/254 [==============================] - 1s 2ms/step - loss: 0.3350 - accuracy: 0.8611 - val_loss: 0.2937 - val_accuracy: 0.8878
# Epoch 32/500
# 254/254 [==============================] - 1s 3ms/step - loss: 0.3353 - accuracy: 0.8605 - val_loss: 0.2937 - val_accuracy: 0.8878
# Epoch 33/500
# 254/254 [==============================] - 1s 3ms/step - loss: 0.3337 - accuracy: 0.8620 - val_loss: 0.3051 - val_accuracy: 0.8778
# Epoch 33: early stopping

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot();

# %%
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print("loss : ", loss)
print("accuracy : ", accuracy)
# Out:
# loss :  0.3536248505115509
# accuracy :  0.843999981880188

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[774  22]
#  [134  70]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.91       796
#            1       0.76      0.34      0.47       204
#
#     accuracy                           0.84      1000
#    macro avg       0.81      0.66      0.69      1000
# weighted avg       0.83      0.84      0.82      1000

# %% [markdown]
# ### 5.2.3. Without class_weight (without Early stop - with limited epochs)

# %%
tf.random.set_seed(seed)

model = Sequential()

model.add(Dense(20, activation = "relu", input_dim = X_train.shape[1]))
model.add(Dense(15, activation = "relu"))
model.add(Dense(10, activation = "relu"))
model.add(Dense(1, activation = "sigmoid"))

model.compile(optimizer = Adam(lr = 0.003), loss = "binary_crossentropy", metrics = ["accuracy"])

# %%
model.fit(x = X_train, y = y_train, validation_split = 0.1, batch_size = 32, epochs = 150, 
          verbose = 1)

# %% [markdown]
# #### Evaluate

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot()
# Out:
# <AxesSubplot:>

# %%
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print("loss : ", loss)
print("accuracy : ", accuracy)
# Out:
# loss :  0.3597605228424072
# accuracy :  0.8550000190734863

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[767  29]
#  [116  88]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91       796
#            1       0.75      0.43      0.55       204
#
#     accuracy                           0.85      1000
#    macro avg       0.81      0.70      0.73      1000
# weighted avg       0.84      0.85      0.84      1000

# %% [markdown]
# ### 5.2.4. With class_weight
#
# Investigate how the "class_weight" hyper-parameter is used in a Neural Network.

# %%
from sklearn.utils import class_weight

# %%
class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y_train),
                                                 y_train)

class_weight_dict = dict(enumerate(class_weights))

# %%
tf.random.set_seed(seed)

model = Sequential()

model.add(Dense(20, activation = "relu", input_dim = X_train.shape[1]))
model.add(Dense(15, activation = "relu"))
model.add(Dense(10, activation = "relu"))
model.add(Dense(1, activation = "sigmoid"))

model.compile(optimizer = Adam(lr = 0.003), loss = "binary_crossentropy", metrics = ["accuracy"])

# %%
model.fit(x = X_train, y = y_train, validation_split = 0.1, batch_size = 32, epochs = 500, 
          class_weight=class_weight_dict, verbose = 1)

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot()
# Out:
# <AxesSubplot:>

# %%
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print("loss : ", loss)
print("accuracy : ", accuracy)
# Out:
# loss :  0.5564883351325989
# accuracy :  0.765999972820282

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[619 177]
#  [ 57 147]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.78      0.84       796
#            1       0.45      0.72      0.56       204
#
#     accuracy                           0.77      1000
#    macro avg       0.68      0.75      0.70      1000
# weighted avg       0.82      0.77      0.78      1000

# %% [markdown]
# ### 5.2.5. With class_weight (2nd trial)

# %%
tf.random.set_seed(seed)

model = Sequential()

model.add(Dense(20, activation = "relu", input_dim = X_train.shape[1]))
model.add(Dense(15, activation = "relu"))
model.add(Dense(10, activation = "relu"))
model.add(Dense(1, activation = "sigmoid"))

model.compile(optimizer = Adam(lr = 0.002), loss = "binary_crossentropy", metrics = ["accuracy"])

# %%
model.fit(x = X_train, y = y_train, validation_split = 0.1, batch_size = 64, epochs = 150, 
          class_weight=class_weight_dict, verbose = 1)

# %% [markdown]
# #### Evaluate

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot()
# Out:
# <AxesSubplot:>

# %%
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print("loss : ", loss)
print("accuracy : ", accuracy)
# Out:
# loss :  0.3958185017108917
# accuracy :  0.8209999799728394

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[684 112]
#  [ 67 137]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.86      0.88       796
#            1       0.55      0.67      0.60       204
#
#     accuracy                           0.82      1000
#    macro avg       0.73      0.77      0.74      1000
# weighted avg       0.84      0.82      0.83      1000

# %% [markdown]
# ## 6. GridSearchCV

# %%
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

# %%
from tensorflow.keras.optimizers import Adam, Adadelta, RMSprop, Nadam

# %%
def build_classifier(optimizer, learn_rate):
    classifier = Sequential()
    classifier.add(Dense(units = 20, activation = 'relu'))
    classifier.add(Dense(units = 15, activation = 'relu'))
    classifier.add(Dense(units = 10, activation = 'relu'))
    classifier.add(Dense(units = 1, activation = 'sigmoid'))
    classifier.compile(optimizer = optimizer(learn_rate), loss = 'binary_crossentropy', metrics = ['accuracy'])
    return classifier

# %%
early_stop = EarlyStopping(monitor = "val_accuracy", mode = "auto", verbose = 0, 
                           patience = 20)

# %%
tf.random.set_seed(seed)

classifier_model = KerasClassifier(build_fn = build_classifier, validation_split = 0.1, 
                                   epochs = 150)

parameters = {'batch_size': [32, 64],
              'optimizer': [Adam, RMSprop, Adadelta, Nadam],
              'learn_rate': [0.001, 0.002],
              'class_weight': [None, class_weight_dict]}

grid_model = GridSearchCV(estimator = classifier_model,
                          param_grid = parameters,
                          scoring = 'accuracy',
                          cv = 5,
                          n_jobs = -1,
                          verbose = 0)

grid_model.fit(X_train, y_train, callbacks = [early_stop])

# %%
grid_model.best_score_
# Out:
# 0.8595555555555556

# %%
grid_model.best_params_
# Out:
# {'batch_size': 32,
#  'class_weight': None,
#  'learn_rate': 0.001,
#  'optimizer': keras.optimizer_v2.nadam.Nadam}

# %%
grid_result = pd.DataFrame(grid_model.cv_results_)[["mean_test_score", "std_test_score", 
                                                    "rank_test_score", "params"]]
grid_result
# Out:
#     mean_test_score  std_test_score  rank_test_score  \
# 0             0.855           0.009                9
# 1             0.853           0.010               12
# 2             0.796           0.008               13
# 3             0.860           0.006                1
# 4             0.855           0.009               10
# 5             0.858           0.005                4
# 6             0.796           0.009               14
# 7             0.857           0.007                6
# 8             0.788           0.016               17
# 9             0.777           0.017               21
# 10            0.543           0.135               31
# 11            0.793           0.026               16
# 12            0.785           0.013               18
# 13            0.762           0.059               26
# 14            0.714           0.079               28
# 15            0.763           0.029               25
# 16            0.854           0.007               11
# 17            0.856           0.006                7
# 18            0.680           0.236               29
# 19            0.856           0.006                8
# 20            0.859           0.010                2
# 21            0.857           0.006                5
# 22            0.796           0.009               14
# 23            0.858           0.005                3
# 24            0.780           0.007               19
# 25            0.774           0.038               22
# 26            0.455           0.190               32
# 27            0.767           0.031               24
# 28            0.773           0.021               23
# 29            0.744           0.062               27
# 30            0.660           0.176               30
# 31            0.778           0.021               20
#
#                                                params
# 0   {'batch_size': 32, 'class_weight': None, 'lear...
# 1   {'batch_size': 32, 'class_weight': None, 'lear...
# 2   {'batch_size': 32, 'class_weight': None, 'lear...
# 3   {'batch_size': 32, 'class_weight': None, 'lear...
# 4   {'batch_size': 32, 'class_weight': None, 'lear...
# 5   {'batch_size': 32, 'class_weight': None, 'lear...
# 6   {'batch_size': 32, 'class_weight': None, 'lear...
# 7   {'batch_size': 32, 'class_weight': None, 'lear...
# 8   {'batch_size': 32, 'class_weight': {0: 0.62787...
# 9   {'batch_size': 32, 'class_weight': {0: 0.62787...
# 10  {'batch_size': 32, 'class_weight': {0: 0.62787...
# 11  {'batch_size': 32, 'class_weight': {0: 0.62787...
# 12  {'batch_size': 32, 'class_weight': {0: 0.62787...
# 13  {'batch_size': 32, 'class_weight': {0: 0.62787...
# 14  {'batch_size': 32, 'class_weight': {0: 0.62787...
# 15  {'batch_size': 32, 'class_weight': {0: 0.62787...
# 16  {'batch_size': 64, 'class_weight': None, 'lear...
# 17  {'batch_size': 64, 'class_weight': None, 'lear...
# 18  {'batch_size': 64, 'class_weight': None, 'lear...
# 19  {'batch_size': 64, 'class_weight': None, 'lear...
# 20  {'batch_size': 64, 'class_weight': None, 'lear...
# 21  {'batch_size': 64, 'class_weight': None, 'lear...
# 22  {'batch_size': 64, 'class_weight': None, 'lear...
# 23  {'batch_size': 64, 'class_weight': None, 'lear...
# 24  {'batch_size': 64, 'class_weight': {0: 0.62787...
# 25  {'batch_size': 64, 'class_weight': {0: 0.62787...
# 26  {'batch_size': 64, 'class_weight': {0: 0.62787...
# 27  {'batch_size': 64, 'class_weight': {0: 0.62787...
# 28  {'batch_size': 64, 'class_weight': {0: 0.62787...
# 29  {'batch_size': 64, 'class_weight': {0: 0.62787...
# 30  {'batch_size': 64, 'class_weight': {0: 0.62787...
# 31  {'batch_size': 64, 'class_weight': {0: 0.62787...

# %%
grid_result.sort_values(by='rank_test_score')
# Out:
#     mean_test_score  std_test_score  rank_test_score  \
# 3             0.860           0.006                1
# 20            0.859           0.010                2
# 23            0.858           0.005                3
# 5             0.858           0.005                4
# 21            0.857           0.006                5
# 7             0.857           0.007                6
# 17            0.856           0.006                7
# 19            0.856           0.006                8
# 0             0.855           0.009                9
# 4             0.855           0.009               10
# 16            0.854           0.007               11
# 1             0.853           0.010               12
# 2             0.796           0.008               13
# 6             0.796           0.009               14
# 22            0.796           0.009               14
# 11            0.793           0.026               16
# 8             0.788           0.016               17
# 12            0.785           0.013               18
# 24            0.780           0.007               19
# 31            0.778           0.021               20
# 9             0.777           0.017               21
# 25            0.774           0.038               22
# 28            0.773           0.021               23
# 27            0.767           0.031               24
# 15            0.763           0.029               25
# 13            0.762           0.059               26
# 29            0.744           0.062               27
# 14            0.714           0.079               28
# 18            0.680           0.236               29
# 30            0.660           0.176               30
# 10            0.543           0.135               31
# 26            0.455           0.190               32
#
#                                                params
# 3   {'batch_size': 32, 'class_weight': None, 'lear...
# 20  {'batch_size': 64, 'class_weight': None, 'lear...
# 23  {'batch_size': 64, 'class_weight': None, 'lear...
# 5   {'batch_size': 32, 'class_weight': None, 'lear...
# 21  {'batch_size': 64, 'class_weight': None, 'lear...
# 7   {'batch_size': 32, 'class_weight': None, 'lear...
# 17  {'batch_size': 64, 'class_weight': None, 'lear...
# 19  {'batch_size': 64, 'class_weight': None, 'lear...
# 0   {'batch_size': 32, 'class_weight': None, 'lear...
# 4   {'batch_size': 32, 'class_weight': None, 'lear...
# 16  {'batch_size': 64, 'class_weight': None, 'lear...
# 1   {'batch_size': 32, 'class_weight': None, 'lear...
# 2   {'batch_size': 32, 'class_weight': None, 'lear...
# 6   {'batch_size': 32, 'class_weight': None, 'lear...
# 22  {'batch_size': 64, 'class_weight': None, 'lear...
# 11  {'batch_size': 32, 'class_weight': {0: 0.62787...
# 8   {'batch_size': 32, 'class_weight': {0: 0.62787...
# 12  {'batch_size': 32, 'class_weight': {0: 0.62787...
# 24  {'batch_size': 64, 'class_weight': {0: 0.62787...
# 31  {'batch_size': 64, 'class_weight': {0: 0.62787...
# 9   {'batch_size': 32, 'class_weight': {0: 0.62787...
# 25  {'batch_size': 64, 'class_weight': {0: 0.62787...
# 28  {'batch_size': 64, 'class_weight': {0: 0.62787...
# 27  {'batch_size': 64, 'class_weight': {0: 0.62787...
# 15  {'batch_size': 32, 'class_weight': {0: 0.62787...
# 13  {'batch_size': 32, 'class_weight': {0: 0.62787...
# 29  {'batch_size': 64, 'class_weight': {0: 0.62787...
# 14  {'batch_size': 32, 'class_weight': {0: 0.62787...
# 18  {'batch_size': 64, 'class_weight': None, 'lear...
# 30  {'batch_size': 64, 'class_weight': {0: 0.62787...
# 10  {'batch_size': 32, 'class_weight': {0: 0.62787...
# 26  {'batch_size': 64, 'class_weight': {0: 0.62787...

# %% [markdown]
# #### Evaluate

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score, roc_curve, roc_auc_score

# %%
y_pred_proba = grid_model.predict(X_test)
fpr, tpr, thresholds = precision_recall_curve(y_test, y_pred_proba)
plt.plot([0,1],[1,0],'k--')
plt.plot(fpr,tpr, label='ANN')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall curve')
plt.show()

# %%
average_precision_score(y_test, y_pred_proba)
# Out:
# 0.45061377945673686

# %%
y_pred_proba = grid_model.predict(X_test)
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr, label='ANN')
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.title('ROC curve')
plt.show()

# %%
roc_auc_score(y_test, y_pred_proba)
# Out:
# 0.6963370775445857

# %% [markdown]
# ## 7. Final Model and Model Deployment

# %%
tf.random.set_seed(seed)

model = Sequential()

model.add(Dense(20, activation = "relu", input_dim = X_train.shape[1]))
model.add(Dense(15, activation = "relu"))
model.add(Dense(10, activation = "relu"))
model.add(Dense(1, activation = "sigmoid"))

model.compile(optimizer = 'Nadam', loss = "binary_crossentropy", metrics = ["accuracy"])

# %%
model.fit(x = X_train, y = y_train, validation_data = (X_test, y_test), batch_size = 32, epochs = 150, verbose = 1)

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.plot();

# %%
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print("loss : ", loss)
print("accuracy : ", accuracy)
# Out:
# loss :  0.3506785035133362
# accuracy :  0.8539999723434448

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[764  32]
#  [114  90]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91       796
#            1       0.74      0.44      0.55       204
#
#     accuracy                           0.85      1000
#    macro avg       0.80      0.70      0.73      1000
# weighted avg       0.84      0.85      0.84      1000

# %%
model.save('assignment1.h5')

# %% [markdown]
# ## 8. Prediction

# %%
from tensorflow.keras.models import load_model

# %%
pred_model = load_model('assignment1.h5')

# %%
obs = df_final.drop('Exited', axis=1).iloc[0:5, :]
obs
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2      0.000              1          1
# 1          608   41       1  83807.860              1          0
# 2          502   42       8 159660.800              3          1
# 3          699   39       1      0.000              2          0
# 4          850   43       2 125510.820              1          1
#
#    IsActiveMember  EstimatedSalary  geo_France  geo_Germany  geo_Spain  \
# 0               1       101348.880           1            0          0
# 1               1       112542.580           0            0          1
# 2               0       113931.570           1            0          0
# 3               0        93826.630           1            0          0
# 4               1        79084.100           0            0          1
#
#    Female  Male
# 0       1     0
# 1       1     0
# 2       1     0
# 3       1     0
# 4       1     0

# %%
obs = scaler.transform(obs)
obs
# Out:
# array([[0.538     , 0.32432432, 0.2       , 0.        , 0.        ,
#         1.        , 1.        , 0.50673489, 1.        , 0.        ,
#         0.        , 1.        , 0.        ],
#        [0.516     , 0.31081081, 0.1       , 0.35156138, 0.        ,
#         0.        , 1.        , 0.56270874, 0.        , 0.        ,
#         1.        , 1.        , 0.        ],
#        [0.304     , 0.32432432, 0.8       , 0.66975307, 0.66666667,
#         1.        , 0.        , 0.56965435, 1.        , 0.        ,
#         0.        , 1.        , 0.        ],
#        [0.698     , 0.28378378, 0.1       , 0.        , 0.33333333,
#         0.        , 0.        , 0.46912005, 1.        , 0.        ,
#         0.        , 1.        , 0.        ],
#        [1.        , 0.33783784, 0.2       , 0.52649903, 0.        ,
#         1.        , 1.        , 0.39540036, 0.        , 0.        ,
#         1.        , 1.        , 0.        ]])

# %%
(pred_model.predict(obs) > 0.5).astype('int32')
# Out:
# array([[0],
#        [0],
#        [1],
#        [0],
#        [0]], dtype=int32)

# %%
df_final['Exited'].iloc[0:5]
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Exited, dtype: int64
